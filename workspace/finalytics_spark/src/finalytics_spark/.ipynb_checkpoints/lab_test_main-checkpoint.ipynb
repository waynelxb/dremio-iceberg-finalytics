# %%
import os
import yaml
import nbimporter
from datetime import datetime, date
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DoubleType,  DateType, TimestampType
from pyspark.sql.functions import to_date, to_timestamp
from lab_table_manager import TableManager
import yfinance as yf
import time
import random
from lab_pg_database_manager import PGDatabaseManager
from lab_raw_yfinance import xparallel_fetch_yfinance_record
from lab_spark import create_spark_session

# %%
import yfinance as yf
from datetime import date
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, DateType, DoubleType, StringType

# # Define the schema for the DataFrame
record_schema = StructType([
    StructField("Date", DateType(), True),
    StructField("Open", DoubleType(), True),
    StructField("High", DoubleType(), True),
    StructField("Low", DoubleType(), True),
    StructField("Close", DoubleType(), True),
    StructField("Volume", DoubleType(), True),
    StructField("Dividends", DoubleType(), True),
    StructField("Stock Splits", DoubleType(), True),
    StructField("Symbol", StringType(), True),
    StructField("ImportTime", StringType(), True)
])

# Example usage
spark=create_spark_session("myspark")
symbol_date_pairs = [("AAPL", "2023-01-01"), ("GOOGL", "2023-01-01")]
result_df = xparallel_fetch_yfinance_record(spark, symbol_date_pairs, record_schema)
result_df.show()
# Out:
# :: loading settings :: url = jar:file:/opt/spark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# org.postgresql#postgresql added as a dependency
# org.apache.iceberg#iceberg-spark-runtime-3.5_2.12 added as a dependency
# org.projectnessie.nessie-integrations#nessie-spark-extensions-3.5_2.12 added as a dependency
# software.amazon.awssdk#bundle added as a dependency
# software.amazon.awssdk#url-connection-client added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-22e41f39-5e03-481a-afe2-d3b4eb22835e;1.0
# 	confs: [default]
# 	found org.postgresql#postgresql;42.7.3 in central
# 	found org.checkerframework#checker-qual;3.42.0 in central
# 	found org.apache.iceberg#iceberg-spark-runtime-3.5_2.12;1.5.0 in central
# 	found org.projectnessie.nessie-integrations#nessie-spark-extensions-3.5_2.12;0.77.1 in central
# 	found software.amazon.awssdk#bundle;2.24.8 in central
# 	found software.amazon.awssdk#url-connection-client;2.24.8 in central
# 	found software.amazon.awssdk#utils;2.24.8 in central
# 	found org.reactivestreams#reactive-streams;1.0.4 in central
# 	found software.amazon.awssdk#annotations;2.24.8 in central
# 	found org.slf4j#slf4j-api;1.7.30 in central
# 	found software.amazon.awssdk#http-client-spi;2.24.8 in central
# 	found software.amazon.awssdk#metrics-spi;2.24.8 in central
# :: resolution report :: resolve 444ms :: artifacts dl 16ms
# 	:: modules in use:
# 	org.apache.iceberg#iceberg-spark-runtime-3.5_2.12;1.5.0 from central in [default]
# 	org.checkerframework#checker-qual;3.42.0 from central in [default]
# 	org.postgresql#postgresql;42.7.3 from central in [default]
# 	org.projectnessie.nessie-integrations#nessie-spark-extensions-3.5_2.12;0.77.1 from central in [default]
# 	org.reactivestreams#reactive-streams;1.0.4 from central in [default]
# 	org.slf4j#slf4j-api;1.7.30 from central in [default]
# 	software.amazon.awssdk#annotations;2.24.8 from central in [default]
# 	software.amazon.awssdk#bundle;2.24.8 from central in [default]
# 	software.amazon.awssdk#http-client-spi;2.24.8 from central in [default]
# 	software.amazon.awssdk#metrics-spi;2.24.8 from central in [default]
# 	software.amazon.awssdk#url-connection-client;2.24.8 from central in [default]
# 	software.amazon.awssdk#utils;2.24.8 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   12  |   0   |   0   |   0   ||   12  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-22e41f39-5e03-481a-afe2-d3b4eb22835e
# 	confs: [default]
# 	0 artifacts copied, 12 already retrieved (0kB/8ms)
# 25/01/04 23:36:43 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Error paralleling fetch: name 'spark' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /workspace/finalytics_spark/src/finalytics_spark/lab_raw_yfinance.ipynb:35, in xparallel_fetch_yfinance_record(symbol_date_pairs, record_schema)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "bc71f1ce-97ce-4e88-a374-747acfc540fd",
#       7    "metadata": {
#       8     "tags": []
#       9    },
#      10    "outputs": [],
#      11    "source": [
#      12     "import os\n",
#      13     "import yaml\n",
#      14     "import nbimporter\n",
#      15     "from datetime import datetime, date\n",
#      16     "import pyspark\n",
#      17     "from pyspark.sql import SparkSession\n",
#      18     "from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DoubleType,  DateType, TimestampType\n",
#      19     "from pyspark.sql.functions import to_date, to_timestamp\n",
#      20     "from lab_table_manager import TableManager\n",
#      21     "import yfinance as yf\n",
#      22     "import time\n",
#      23     "import random\n",
#      24     "from lab_pg_database_manager import PGDatabaseManager"
#      25    ]
#      26   },
#      27   {
#      28    "cell_type": "code",
#      29    "execution_count": 2,
#      30    "id": "43f1668e-6c02-40a4-8d8b-4c1e522420fb",
#      31    "metadata": {
#      32     "tags": []
#      33    },
#      34    "outputs": [],
# ---> 35    "source": [
#      36     "def fetch_yfinance_record(symbol_date_pairs):\n",
#      37     "    try:\n",
#      38     "        symbol, start_date = symbol_date_pairs\n",
#      39     "        # Fetch stock data using yfinance\n",
#      40     "        quote = yf.Ticker(symbol)\n",
#      41     "        current_date = date.today()\n",
#      42     "        hist = quote.history(start=start_date, end=current_date)\n",
#      43     "\n",
#      44     "        # Reset index to include Date as a column and format it\n",
#      45     "        hist.reset_index(inplace=True)\n",
#      46     "        hist[\"Date\"] = hist[\"Date\"].dt.date\n",
#      47     "        \n",
#      48     "        # limit and stablize the fields of hist\n",
#      49     "        hist = hist[['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']]\n",
#      50     "        \n",
#      51     "        # Add symbol and import_time to each row\n",
#      52     "        record_list = [\n",
#      53     "            tuple(row) + (symbol, import_time) for row in hist.itertuples(index=False)\n",
#      54     "        ]\n",
#      55     "        random_sleep_time = random.uniform(0.1, 0.9)\n",
#      56     "        time.sleep(random_sleep_time)\n",
#      57     "\n",
#      58     "        # print(record_list)\n",
#      59     "        return record_list\n",
#      60     "\n",
#      61     "    except Exception as e:\n",
#      62     "        print(f\"Error fetching data for {symbol}: {e}\")\n",
#      63     "        return []  # Return an empty list on error"
#      64    ]
#      65   },
#      66   {
#      67    "cell_type": "code",
#      68    "execution_count": null,
#      69    "id": "d738cd69-ec1e-4273-a825-268cce1a14c8",
#      70    "metadata": {},
#      71    "outputs": [],
#      72    "source": [
#      73     "import yfinance as yf\n",
#      74     "from datetime import date\n",
#      75     "import time\n",
#      76     "import random\n",
#      77     "from pyspark.sql import SparkSession\n",
#      78     "from pyspark.sql.types import StructType, StructField, DateType, DoubleType, StringType\n",
#      79     "\n",
#      80     "# # Define the schema for the DataFrame\n",
#      81     "record_schema = StructType([\n",
#      82     "    StructField(\"Date\", DateType(), True),\n",
#      83     "    StructField(\"Open\", DoubleType(), True),\n",
#      84     "    StructField(\"High\", DoubleType(), True),\n",
#      85     "    StructField(\"Low\", DoubleType(), True),\n",
#      86     "    StructField(\"Close\", DoubleType(), True),\n",
#      87     "    StructField(\"Volume\", DoubleType(), True),\n",
#      88     "    StructField(\"Dividends\", DoubleType(), True),\n",
#      89     "    StructField(\"Stock Splits\", DoubleType(), True),\n",
#      90     "    StructField(\"Symbol\", StringType(), True),\n",
#      91     "    StructField(\"ImportTime\", StringType(), True)\n",
#      92     "])\n",
#      93     "\n",
#      94     "\n",
#      95     "\n",
#      96     "def xparallel_fetch_yfinance_record(symbol_date_pairs, record_schema):\n",
#      97     "    try:\n",
#      98     "        # Initialize Spark session\n",
#      99     "\n",
#     100     "        connection_config_file=\"cfg_connections.yaml\"\n",
#     101     "        spark_app_name=\"YFinanceDataFetcher\"\n",
#     102     "        # spark=create_spark_session(spark_app_name)\n",
#     103     "        \n",
#     104     "        # spark = SparkSession.builder.appName(\"YFinanceDataFetcher\").getOrCreate()\n",
#     105     "        \n",
#     106     "        # Distribute (symbol, start_date) pairs across Spark workers\n",
#     107     "        record_rdd = spark.sparkContext.parallelize(symbol_date_pairs)\n",
#     108     "        \n",
#     109     "        # Fetch data in parallel using mapPartitions to avoid broadcasting Spark session\n",
#     110     "        mapped_record_rdd = record_rdd.mapPartitions(lambda partition: [record for pair in partition for record in fetch_yfinance_record(pair)])\n",
#     111     "        \n",
#     112     "        # Convert RDD to DataFrame on the driver node\n",
#     113     "        result_df = spark.createDataFrame(mapped_record_rdd)  \n",
#     114     "\n",
#     115     "        return result_df\n",
#     116     "    except Exception as e:\n",
#     117     "        print(f\"Error paralleling fetch: {e}\")\n",
#     118     "        return spark.createDataFrame([])\n",
#     119     "  \n",
#     120     "\n",
#     121     "# Example usage\n",
#     122     "spark=create_spark_session(\"myspark\")\n",
#     123     "symbol_date_pairs = [(\"AAPL\", \"2023-01-01\"), (\"GOOGL\", \"2023-01-01\")]\n",
#     124     "result_df = xparallel_fetch_yfinance_record(symbol_date_pairs, record_schema)\n",
#     125     "result_df.show()"
#     126    ]
#     127   },
#     128   {
#     129    "cell_type": "code",
#     130    "execution_count": null,
#     131    "id": "afb0f932-927f-4318-8e24-303d2424ba4e",
#     132    "metadata": {},
#     133    "outputs": [],
#     134    "source": [
#     135     "result_df.show()"
#     136    ]
#     137   },
#     138   {
#     139    "cell_type": "code",
#     140    "execution_count": null,
#     141    "id": "eb81d18d-f8df-4805-aaf2-f5a5b48d9d52",
#     142    "metadata": {},
#     143    "outputs": [],
#     144    "source": []
#     145   }
#     146  ],
#     147  "metadata": {
#     148   "kernelspec": {
#     149    "display_name": "Poetry",
#     150    "language": "python",
#     151    "name": "poetry-kernel"
#     152   },
#     153   "language_info": {
#     154    "codemirror_mode": {
#     155     "name": "ipython",
#     156     "version": 3
#     157    },
#     158    "file_extension": ".py",
#     159    "mimetype": "text/x-python",
#     160    "name": "python",
#     161    "nbconvert_exporter": "python",
#     162    "pygments_lexer": "ipython3",
#     163    "version": "3.10.12"
#     164   }
#     165  },
#     166  "nbformat": 4,
#     167  "nbformat_minor": 5
#     168 }
#
# NameError: name 'spark' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 23
#      21 spark=create_spark_session("myspark")
#      22 symbol_date_pairs = [("AAPL", "2023-01-01"), ("GOOGL", "2023-01-01")]
# ---> 23 result_df = xparallel_fetch_yfinance_record(symbol_date_pairs, record_schema)
#      24 result_df.show()
#
# File /workspace/finalytics_spark/src/finalytics_spark/lab_raw_yfinance.ipynb:46, in xparallel_fetch_yfinance_record(symbol_date_pairs, record_schema)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "bc71f1ce-97ce-4e88-a374-747acfc540fd",
#       7    "metadata": {
#       8     "tags": []
#       9    },
#      10    "outputs": [],
#      11    "source": [
#      12     "import os\n",
#      13     "import yaml\n",
#      14     "import nbimporter\n",
#      15     "from datetime import datetime, date\n",
#      16     "import pyspark\n",
#      17     "from pyspark.sql import SparkSession\n",
#      18     "from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DoubleType,  DateType, TimestampType\n",
#      19     "from pyspark.sql.functions import to_date, to_timestamp\n",
#      20     "from lab_table_manager import TableManager\n",
#      21     "import yfinance as yf\n",
#      22     "import time\n",
#      23     "import random\n",
#      24     "from lab_pg_database_manager import PGDatabaseManager"
#      25    ]
#      26   },
#      27   {
#      28    "cell_type": "code",
#      29    "execution_count": 2,
#      30    "id": "43f1668e-6c02-40a4-8d8b-4c1e522420fb",
#      31    "metadata": {
#      32     "tags": []
#      33    },
#      34    "outputs": [],
#      35    "source": [
#      36     "def fetch_yfinance_record(symbol_date_pairs):\n",
#      37     "    try:\n",
#      38     "        symbol, start_date = symbol_date_pairs\n",
#      39     "        # Fetch stock data using yfinance\n",
#      40     "        quote = yf.Ticker(symbol)\n",
#      41     "        current_date = date.today()\n",
#      42     "        hist = quote.history(start=start_date, end=current_date)\n",
#      43     "\n",
#      44     "        # Reset index to include Date as a column and format it\n",
#      45     "        hist.reset_index(inplace=True)\n",
# ---> 46     "        hist[\"Date\"] = hist[\"Date\"].dt.date\n",
#      47     "        \n",
#      48     "        # limit and stablize the fields of hist\n",
#      49     "        hist = hist[['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']]\n",
#      50     "        \n",
#      51     "        # Add symbol and import_time to each row\n",
#      52     "        record_list = [\n",
#      53     "            tuple(row) + (symbol, import_time) for row in hist.itertuples(index=False)\n",
#      54     "        ]\n",
#      55     "        random_sleep_time = random.uniform(0.1, 0.9)\n",
#      56     "        time.sleep(random_sleep_time)\n",
#      57     "\n",
#      58     "        # print(record_list)\n",
#      59     "        return record_list\n",
#      60     "\n",
#      61     "    except Exception as e:\n",
#      62     "        print(f\"Error fetching data for {symbol}: {e}\")\n",
#      63     "        return []  # Return an empty list on error"
#      64    ]
#      65   },
#      66   {
#      67    "cell_type": "code",
#      68    "execution_count": null,
#      69    "id": "d738cd69-ec1e-4273-a825-268cce1a14c8",
#      70    "metadata": {},
#      71    "outputs": [],
#      72    "source": [
#      73     "import yfinance as yf\n",
#      74     "from datetime import date\n",
#      75     "import time\n",
#      76     "import random\n",
#      77     "from pyspark.sql import SparkSession\n",
#      78     "from pyspark.sql.types import StructType, StructField, DateType, DoubleType, StringType\n",
#      79     "\n",
#      80     "# # Define the schema for the DataFrame\n",
#      81     "record_schema = StructType([\n",
#      82     "    StructField(\"Date\", DateType(), True),\n",
#      83     "    StructField(\"Open\", DoubleType(), True),\n",
#      84     "    StructField(\"High\", DoubleType(), True),\n",
#      85     "    StructField(\"Low\", DoubleType(), True),\n",
#      86     "    StructField(\"Close\", DoubleType(), True),\n",
#      87     "    StructField(\"Volume\", DoubleType(), True),\n",
#      88     "    StructField(\"Dividends\", DoubleType(), True),\n",
#      89     "    StructField(\"Stock Splits\", DoubleType(), True),\n",
#      90     "    StructField(\"Symbol\", StringType(), True),\n",
#      91     "    StructField(\"ImportTime\", StringType(), True)\n",
#      92     "])\n",
#      93     "\n",
#      94     "\n",
#      95     "\n",
#      96     "def xparallel_fetch_yfinance_record(symbol_date_pairs, record_schema):\n",
#      97     "    try:\n",
#      98     "        # Initialize Spark session\n",
#      99     "\n",
#     100     "        connection_config_file=\"cfg_connections.yaml\"\n",
#     101     "        spark_app_name=\"YFinanceDataFetcher\"\n",
#     102     "        # spark=create_spark_session(spark_app_name)\n",
#     103     "        \n",
#     104     "        # spark = SparkSession.builder.appName(\"YFinanceDataFetcher\").getOrCreate()\n",
#     105     "        \n",
#     106     "        # Distribute (symbol, start_date) pairs across Spark workers\n",
#     107     "        record_rdd = spark.sparkContext.parallelize(symbol_date_pairs)\n",
#     108     "        \n",
#     109     "        # Fetch data in parallel using mapPartitions to avoid broadcasting Spark session\n",
#     110     "        mapped_record_rdd = record_rdd.mapPartitions(lambda partition: [record for pair in partition for record in fetch_yfinance_record(pair)])\n",
#     111     "        \n",
#     112     "        # Convert RDD to DataFrame on the driver node\n",
#     113     "        result_df = spark.createDataFrame(mapped_record_rdd)  \n",
#     114     "\n",
#     115     "        return result_df\n",
#     116     "    except Exception as e:\n",
#     117     "        print(f\"Error paralleling fetch: {e}\")\n",
#     118     "        return spark.createDataFrame([])\n",
#     119     "  \n",
#     120     "\n",
#     121     "# Example usage\n",
#     122     "spark=create_spark_session(\"myspark\")\n",
#     123     "symbol_date_pairs = [(\"AAPL\", \"2023-01-01\"), (\"GOOGL\", \"2023-01-01\")]\n",
#     124     "result_df = xparallel_fetch_yfinance_record(symbol_date_pairs, record_schema)\n",
#     125     "result_df.show()"
#     126    ]
#     127   },
#     128   {
#     129    "cell_type": "code",
#     130    "execution_count": null,
#     131    "id": "afb0f932-927f-4318-8e24-303d2424ba4e",
#     132    "metadata": {},
#     133    "outputs": [],
#     134    "source": [
#     135     "result_df.show()"
#     136    ]
#     137   },
#     138   {
#     139    "cell_type": "code",
#     140    "execution_count": null,
#     141    "id": "eb81d18d-f8df-4805-aaf2-f5a5b48d9d52",
#     142    "metadata": {},
#     143    "outputs": [],
#     144    "source": []
#     145   }
#     146  ],
#     147  "metadata": {
#     148   "kernelspec": {
#     149    "display_name": "Poetry",
#     150    "language": "python",
#     151    "name": "poetry-kernel"
#     152   },
#     153   "language_info": {
#     154    "codemirror_mode": {
#     155     "name": "ipython",
#     156     "version": 3
#     157    },
#     158    "file_extension": ".py",
#     159    "mimetype": "text/x-python",
#     160    "name": "python",
#     161    "nbconvert_exporter": "python",
#     162    "pygments_lexer": "ipython3",
#     163    "version": "3.10.12"
#     164   }
#     165  },
#     166  "nbformat": 4,
#     167  "nbformat_minor": 5
#     168 }
#
# NameError: name 'spark' is not defined
